# %% [markdown]
# ### 1. Build the docker image for the model

# %%
# %%sh
#
# # The name of our algorithm
# #algorithm_name=pytorch-extending-our-containers-cifar10-example
# algorithm_name=model-1-graph2graph-gpu
#
# cd container
#
# account=$(aws sts get-caller-identity --query Account --output text)
#
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# region=${region:-us-west-2}
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${algorithm_name}:latest"
#
# # If the repository doesn't exist in ECR, create it.
#
# aws ecr describe-repositories --repository-names "${algorithm_name}" > /dev/null 2>&1
#
# if [ $? -ne 0 ]
# then
#     aws ecr create-repository --repository-name "${algorithm_name}" > /dev/null
# fi
#
# # Get the login command from ECR and execute it directly
# $(aws ecr get-login --region ${region} --no-include-email)
#
# # Get the login command from ECR in order to pull down the SageMaker PyTorch image
# $(aws ecr get-login --registry-ids 520713654638 --region ${region} --no-include-email)
#
# # Build the docker image locally with the image name and then push it to ECR
# # with the full name.
#
# docker build  -t ${algorithm_name} . --build-arg REGION=${region}
# docker tag ${algorithm_name} ${fullname}
#
# docker push ${fullname}
# Out:
# Login Succeeded
# Login Succeeded
# Sending build context to Docker daemon  14.34kB
# Step 1/6 : ARG REGION=us-west-2
# Step 2/6 : FROM 520713654638.dkr.ecr.$REGION.amazonaws.com/sagemaker-pytorch:0.4.0-cpu-py3
# 0.4.0-cpu-py3: Pulling from sagemaker-pytorch
# 6b524a54a844: Pulling fs layer
# 65b9175cb1f0: Pulling fs layer
# 99f3f7db9f39: Pulling fs layer
# 98f58a51cdc0: Pulling fs layer
# e4fcbd76f95b: Pulling fs layer
# bab6d6e13f8b: Pulling fs layer
# 196bb884b873: Pulling fs layer
# f9c314f81719: Pulling fs layer
# 0e7c80dae4bb: Pulling fs layer
# 6adca18c522e: Pulling fs layer
# 64f29009eb35: Pulling fs layer
# 3fc548ae183b: Pulling fs layer
# 196bb884b873: Waiting
# f9c314f81719: Waiting
# 0e7c80dae4bb: Waiting
# 6adca18c522e: Waiting
# 64f29009eb35: Waiting
# 3fc548ae183b: Waiting
# 98f58a51cdc0: Waiting
# e4fcbd76f95b: Waiting
# bab6d6e13f8b: Waiting
# 65b9175cb1f0: Verifying Checksum
# 65b9175cb1f0: Download complete
# 99f3f7db9f39: Verifying Checksum
# 99f3f7db9f39: Download complete
# 98f58a51cdc0: Verifying Checksum
# 98f58a51cdc0: Download complete
# bab6d6e13f8b: Download complete
# 6b524a54a844: Verifying Checksum
# 6b524a54a844: Download complete
# f9c314f81719: Verifying Checksum
# f9c314f81719: Download complete
# 0e7c80dae4bb: Verifying Checksum
# 0e7c80dae4bb: Download complete
# 6adca18c522e: Verifying Checksum
# 6adca18c522e: Download complete
# 64f29009eb35: Verifying Checksum
# 64f29009eb35: Download complete
# 3fc548ae183b: Verifying Checksum
# 3fc548ae183b: Download complete
# e4fcbd76f95b: Verifying Checksum
# e4fcbd76f95b: Download complete
# 6b524a54a844: Pull complete
# 65b9175cb1f0: Pull complete
# 99f3f7db9f39: Pull complete
# 98f58a51cdc0: Pull complete
# 196bb884b873: Verifying Checksum
# 196bb884b873: Download complete
# e4fcbd76f95b: Pull complete
# bab6d6e13f8b: Pull complete
# 196bb884b873: Pull complete
# f9c314f81719: Pull complete
# 0e7c80dae4bb: Pull complete
# 6adca18c522e: Pull complete
# 64f29009eb35: Pull complete
# 3fc548ae183b: Pull complete
# Digest: sha256:75569b4b554eed51b050b5f6df3d62c423339affd1a47bef4de361056d49cf18
# Status: Downloaded newer image for 520713654638.dkr.ecr.us-east-2.amazonaws.com/sagemaker-pytorch:0.4.0-cpu-py3
#  ---> 11e92f8d88a4
# Step 3/6 : ENV PATH="/opt/ml/code:${PATH}"
#  ---> Running in 047849aa32a4
# Removing intermediate container 047849aa32a4
#  ---> 22c510b9e585
# Step 4/6 : COPY /cifar10 /opt/ml/code
#  ---> e0e86498867c
# Step 5/6 : ENV SAGEMAKER_SUBMIT_DIRECTORY /opt/ml/code
#  ---> Running in f810f00fb9ee
# Removing intermediate container f810f00fb9ee
#  ---> fdfa6ebaaf24
# Step 6/6 : ENV SAGEMAKER_PROGRAM cifar10.py
#  ---> Running in af167593a3ef
# Removing intermediate container af167593a3ef
#  ---> 913071e83d26
# Successfully built 913071e83d26
# Successfully tagged pytorch-extending-our-containers-cifar10-example:latest
# The push refers to repository [739085167460.dkr.ecr.us-east-2.amazonaws.com/pytorch-extending-our-containers-cifar10-example]
# 92af458f91a3: Preparing
# 1e95f2314d9e: Preparing
# 6925e67bc96f: Preparing
# 92767847d831: Preparing
# c6618b7eae39: Preparing
# 7088d75c498e: Preparing
# ee905f515781: Preparing
# 9fb660580ee6: Preparing
# ebf8767b42f1: Preparing
# 3db5746c911a: Preparing
# 819a824caf70: Preparing
# 647265b9d8bc: Preparing
# 41c002c8a6fd: Preparing
# 7088d75c498e: Waiting
# ee905f515781: Waiting
# 9fb660580ee6: Waiting
# ebf8767b42f1: Waiting
# 3db5746c911a: Waiting
# 819a824caf70: Waiting
# 41c002c8a6fd: Waiting
# 647265b9d8bc: Waiting
# 92af458f91a3: Pushed
# c6618b7eae39: Pushed
# 6925e67bc96f: Pushed
# 92767847d831: Pushed
# 7088d75c498e: Pushed
# 3db5746c911a: Pushed
# 1e95f2314d9e: Pushed
# 819a824caf70: Pushed
# 9fb660580ee6: Pushed
# 647265b9d8bc: Pushed
# 41c002c8a6fd: Pushed
# ebf8767b42f1: Pushed
# ee905f515781: Pushed
# latest: digest: sha256:05f659f72f46bf901572ce947508f408d7fb496378a307ee9126f57d808da217 size: 3036
# /home/ec2-user/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages/OpenSSL/crypto.py:12: CryptographyDeprecationWarning: Python 2 is no longer supported by the Python core team. Support for it is now deprecated in cryptography, and will be removed in the next release.
#   from cryptography import x509
# /home/ec2-user/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages/OpenSSL/crypto.py:12: CryptographyDeprecationWarning: Python 2 is no longer supported by the Python core team. Support for it is now deprecated in cryptography, and will be removed in the next release.
#   from cryptography import x509
# /home/ec2-user/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages/OpenSSL/crypto.py:12: CryptographyDeprecationWarning: Python 2 is no longer supported by the Python core team. Support for it is now deprecated in cryptography, and will be removed in the next release.
#   from cryptography import x509
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# /home/ec2-user/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages/OpenSSL/crypto.py:12: CryptographyDeprecationWarning: Python 2 is no longer supported by the Python core team. Support for it is now deprecated in cryptography, and will be removed in the next release.
#   from cryptography import x509
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
